# %%
import numpy as np
import random
import os
import sys
import matplotlib.pyplot as  plt
import pandas as pd
from pandas import read_table, read_csv
import seaborn as sns

# %%
df = read_csv("hcc_dataset.csv")
print(df)
# Out:
#      Gender Symptoms Alcohol HBsAg HBeAg HBcAb HCVAb Cirrhosis Endemic  \
# 0      Male       No     Yes    No    No    No    No       Yes      No
# 1    Female        ?      No    No    No    No   Yes       Yes       ?
# 2      Male       No     Yes   Yes    No   Yes    No       Yes      No
# 3      Male      Yes     Yes    No    No    No    No       Yes      No
# 4      Male      Yes     Yes   Yes    No   Yes    No       Yes      No
# ..      ...      ...     ...   ...   ...   ...   ...       ...     ...
# 160  Female       No     Yes     ?     ?     ?   Yes       Yes      No
# 161  Female      Yes      No     ?     ?     ?     ?       Yes      No
# 162    Male       No     Yes    No    No    No    No       Yes      No
# 163    Male       No     Yes   Yes    No   Yes   Yes       Yes     Yes
# 164    Male      Yes     Yes    No    No    No   Yes       Yes      No
#
#     Smoking  ...  ALP   TP Creatinine Nodules Major_Dim Dir_Bil Iron Sat  \
# ...

# %%
hcc_data = pd.read_csv('hcc_dataset.csv', na_values=['?'])

# %%
hcc_data.describe()
# Out:
#               Age   Grams_day  Packs_year         INR           AFP  \
# count  165.000000  117.000000  112.000000  161.000000  1.570000e+02
# mean    64.690909   71.008547   20.464286    1.421851  1.929995e+04
# std     13.319534   76.277680   51.565130    0.477816  1.490983e+05
# min     20.000000    0.000000    0.000000    0.840000  1.200000e+00
# 25%     57.000000    0.000000    0.000000    1.170000  5.200000e+00
# 50%     66.000000   75.000000    0.000000    1.300000  3.300000e+01
# 75%     74.000000  100.000000   30.500000    1.530000  6.150000e+02
# max     93.000000  500.000000  510.000000    4.820000  1.810346e+06
#
#        Hemoglobin         MCV    Leucocytes      Platelets     Albumin  ...  \
# count  162.000000  162.000000    162.000000     162.000000  159.000000  ...
# mean    12.879012   95.119753   1473.961549  113206.442654    3.445535  ...
# std      2.145237    8.405846   2909.106006  107118.632481    0.685132  ...
# ...

# %%
gender_counts = hcc_data['Gender'].value_counts()

plt.bar(gender_counts.index, gender_counts.values)
# Out:
# <BarContainer object of 2 artists>

# %%
gender_counts = hcc_data['Gender'].value_counts()
print(gender_counts)
# Out:
# Gender
# Male      133
# Female     32
# Name: count, dtype: int64

# %%
_counts = hcc_data['Symptoms'].value_counts()
print(_counts)
# Out:
# Symptoms
# Yes    94
# No     53
# Name: count, dtype: int64

# %%
_counts = hcc_data['Alcohol'].value_counts()
print(_counts)
# Out:
# Alcohol
# Yes    122
# No      43
# Name: count, dtype: int64

# %%
_counts = hcc_data['HBsAg'].value_counts()
print(_counts)
# Out:
# HBsAg
# No     132
# Yes     16
# Name: count, dtype: int64

# %%
_counts = hcc_data['HBeAg'].value_counts()
print(_counts)
# Out:
# HBeAg
# No     125
# Yes      1
# Name: count, dtype: int64

# %%
_counts = hcc_data['HBcAb'].value_counts()
print(_counts)
# Out:
# HBcAb
# No     103
# Yes     38
# Name: count, dtype: int64

# %%
_counts = hcc_data['HCVAb'].value_counts()
print(_counts)
# Out:
# HCVAb
# No     122
# Yes     34
# Name: count, dtype: int64

# %%
_counts = hcc_data['Cirrhosis'].value_counts()
print(_counts)
# Out:
# Cirrhosis
# Yes    149
# No      16
# Name: count, dtype: int64

# %%
_counts = hcc_data['Endemic'].value_counts()
print(_counts)
# Out:
# Endemic
# No     116
# Yes     10
# Name: count, dtype: int64

# %%
_counts = hcc_data['Smoking'].value_counts()
print(_counts)
# Out:
# Smoking
# Yes    63
# No     61
# Name: count, dtype: int64

# %%
_counts = hcc_data['Diabetes'].value_counts()
print(_counts)
# Out:
# Diabetes
# No     106
# Yes     56
# Name: count, dtype: int64

# %%
_counts = hcc_data['Obesity'].value_counts()
print(_counts)
# Out:
# Obesity
# No     135
# Yes     20
# Name: count, dtype: int64

# %%
_counts = hcc_data['Hemochro'].value_counts()
print(_counts)
# Out:
# Hemochro
# No     135
# Yes      7
# Name: count, dtype: int64

# %%
_counts = hcc_data['AHT'].value_counts()
print(_counts)
# Out:
# AHT
# No     103
# Yes     59
# Name: count, dtype: int64

# %%
_counts = hcc_data['CRI'].value_counts()
print(_counts)
# Out:
# CRI
# No     143
# Yes     20
# Name: count, dtype: int64

# %%
_counts = hcc_data['HIV'].value_counts()
print(_counts)
# Out:
# HIV
# No     148
# Yes      3
# Name: count, dtype: int64

# %%
_counts = hcc_data['NASH'].value_counts()
print(_counts)
# Out:
# NASH
# No     135
# Yes      8
# Name: count, dtype: int64

# %%
_counts = hcc_data['Varices'].value_counts()
print(_counts)
# Out:
# Varices
# Yes    69
# No     44
# Name: count, dtype: int64

# %%
_counts = hcc_data['Spleno'].value_counts()
print(_counts)
# Out:
# Spleno
# Yes    84
# No     66
# Name: count, dtype: int64

# %%
_counts = hcc_data['PHT'].value_counts()
print(_counts)
# Out:
# PHT
# Yes    110
# No      44
# Name: count, dtype: int64

# %%
_counts = hcc_data['PVT'].value_counts()
print(_counts)
# Out:
# PVT
# No     126
# Yes     36
# Name: count, dtype: int64

# %%
_counts = hcc_data['Metastasis'].value_counts()
print(_counts)
# Out:
# Metastasis
# No     125
# Yes     36
# Name: count, dtype: int64

# %%
_counts = hcc_data['Hallmark'].value_counts()
print(_counts)
# Out:
# Hallmark
# Yes    111
# No      52
# Name: count, dtype: int64

# %%
_counts = hcc_data['Age'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 51 artists>

# %%
_counts = hcc_data['Grams_day'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 19 artists>

# %%
_counts = hcc_data['Packs_year'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 30 artists>

# %%
_counts = hcc_data['PS'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 5 artists>

# %%
_counts = hcc_data['Encephalopathy'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 2 artists>

# %%
_counts = hcc_data['Ascites'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 2 artists>

# %%
_counts = hcc_data['INR'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 87 artists>

# %%
_counts = hcc_data['AFP'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 132 artists>

# %%
_counts = hcc_data['Hemoglobin'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 71 artists>

# %%
_counts = hcc_data['MCV'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 128 artists>

# %%
_counts = hcc_data['Leucocytes'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 105 artists>

# %%
_counts = hcc_data['Platelets'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 131 artists>

# %%
#_counts = hcc_data['Albumin'].value_counts()

#plt.bar(_counts.index, _counts.values)

# %%
_counts = hcc_data['Total_Bil'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 62 artists>

# %%
_counts = hcc_data['ALT'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 93 artists>

# %%
_counts = hcc_data['AST'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 107 artists>

# %%
_counts = hcc_data['GGT'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 139 artists>

# %%
_counts = hcc_data['ALP'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 124 artists>

# %%
_counts = hcc_data['TP'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 46 artists>

# %%
_counts = hcc_data['Creatinine'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 84 artists>

# %%
_counts = hcc_data['Nodules'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 6 artists>

# %%
_counts = hcc_data['Major_Dim'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 68 artists>

# %%
_counts = hcc_data['Dir_Bil'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 41 artists>

# %%
_counts = hcc_data['Iron'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 68 artists>

# %%
_counts = hcc_data['Sat'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 57 artists>

# %%
_counts = hcc_data['Ferritin'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 84 artists>

# %%
_counts = hcc_data['Class'].value_counts()

plt.bar(_counts.index, _counts.values)
# Out:
# <BarContainer object of 2 artists>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Class', hue='Gender', data=hcc_data)
plt.title('Survival Status by Gender')
plt.xlabel('Class')
plt.ylabel('Count')
plt.legend(title='Gender')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
df.replace({'Male': 0, 'Female': 1, 'No': 0, 'Yes': 1, 'Active': 0, 'Ambulatory': 1,'Restricted': 2, 'Selfcare': 3, 'Disabled': 4, 'Grade I/II': 1, 'Grade III/IV': 2, 'Mild': 1, 'Moderate/Severe': 2}, inplace=True)

enc = LabelEncoder()
df['Class'] = enc.fit_transform(df['Class'])

corr_features = {}

for feature in df.columns:
    if feature != 'Class':
        temp = df.loc[df[feature].notnull(), [feature, 'Class']]
        r_pb, p_value = stats.pointbiserialr(temp[feature], temp['Class'])
        corr_features[feature] = r_pb

corr_features = {key: val for key, val in sorted(corr_features.items(), key = lambda ele: ele[1])}

plt.figure(dpi=100, figsize=(8, 10))
plt.barh(list(corr_features.keys()), list(corr_features.values()))
# Out:
# C:\Users\Soraia\AppData\Local\Temp\ipykernel_14400\381667677.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'Male': 0, 'Female': 1, 'No': 0, 'Yes': 1, 'Active': 0, 'Ambulatory': 1,'Restricted': 2, 'Selfcare': 3, 'Disabled': 4, 'Grade I/II': 1, 'Grade III/IV': 2, 'Mild': 1, 'Moderate/Severe': 2}, inplace=True)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 12
#      10     if feature != 'Class':
#      11         temp = df.loc[df[feature].notnull(), [feature, 'Class']]
# ---> 12         r_pb, p_value = stats.pointbiserialr(temp[feature], temp['Class'])
#      13         corr_features[feature] = r_pb
# ...

# %%
corr_features = {key: abs(value) for key, value in corr_features.items()}
corr_features = {key: val for key, val in sorted(corr_features.items(), key = lambda ele: ele[1])}

best_features = list(corr_features.keys())[-9::]
best_features

# %%
X = df[best_features]
X

# %%
from sklearn.impute import KNNImputer

for var in ['Dir_Bil', ' Albumin', 'Iron', 'Hemoglobin', 'ALP', 'Ferritin']:
    column_data = X[[var]].values
    imputer = KNNImputer(n_neighbors=3)
    imputed_column = imputer.fit_transform(column_data)
    X[var] = imputed_column

# %% [markdown]
# ## Predictive Modeling

# %%
columns = ['Age']

# Function to remove outliers using IQR method
def remove_outliers_iqr(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.00001)
        Q3 = df[column].quantile(0.99999)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

# Remove outliers from specified columns
data_no_outliers = remove_outliers_iqr(df, columns)

# Display the shape of the new DataFrame
print("Original data shape:", df.shape)
print("Data shape after removing outliers:", data_no_outliers.shape)
# Out:
# Original data shape: (165, 50)
# Data shape after removing outliers: (165, 50)

# %%
# Verify data after removing outliers
print(data_no_outliers.info())
print(data_no_outliers.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161 entries, 0 to 164
# Data columns (total 50 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          161 non-null    object
#  1   Symptoms        161 non-null    object
#  2   Alcohol         161 non-null    object
#  3   HBsAg           161 non-null    object
#  4   HBeAg           161 non-null    object
#  5   HBcAb           161 non-null    object
#  6   HCVAb           161 non-null    object
#  7   Cirrhosis       161 non-null    object
#  8   Endemic         161 non-null    object
#  9   Smoking         161 non-null    object
#  10  Diabetes        161 non-null    object
#  11  Obesity         161 non-null    object
#  12  Hemochro        161 non-null    object
#  13  AHT             161 non-null    object
#  14  CRI             161 non-null    object
#  15  HIV             161 non-null    object
#  16  NASH            161 non-null    object
# ...

# %%
#usar os outliers como uma flag para perceber se nos doentes com muitos outliers estes seguem alguma logica.
